# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df=pd.read_csv('/content/breast-cancer.csv')
df=df.drop(['id','Unnamed: 32'],axis=1)
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1}).astype(int)
df.sample(10)
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 211          1       11.840         18.94           75.51      428.0
# 407          1       12.850         21.37           82.63      514.5
# 22           0       15.340         14.26          102.50      704.4
# 336          1       12.990         14.23           84.08      514.3
# 229          0       12.830         22.33           85.26      503.2
# 350          1       11.660         17.07           73.70      421.0
# 450          1       11.870         21.54           76.83      432.0
# 447          1       14.800         17.66           95.88      674.8
# 314          1        8.597         18.60           54.09      221.2
# 318          1        9.042         18.90           60.07      244.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 211          0.08871           0.06900        0.026690              0.01393
# 407          0.07551           0.08316        0.061260              0.01867
# 22           0.10730           0.21350        0.207700              0.09756
# 336          0.09462           0.09965        0.037380              0.02098
# 229          0.10880           0.17990        0.169500              0.06861
# 350          0.07561           0.03630        0.008306              0.01162
# 450          0.06613           0.10640        0.087770              0.02386
# 447          0.09179           0.08890        0.040690              0.02260
# 314          0.10740           0.05847        0.000000              0.00000
# 318          0.09968           0.19720        0.197500              0.04908
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 211         0.1533  ...        13.300          24.99            85.22
# 407         0.1580  ...        14.400          27.01            91.63
# 22          0.2521  ...        18.070          19.08           125.10
# 336         0.1652  ...        13.720          16.91            87.38
# 229         0.2123  ...        15.200          30.15           105.30
# 350         0.1671  ...        13.280          19.74            83.61
# 450         0.1349  ...        12.790          28.18            83.51
# 447         0.1893  ...        16.430          22.74           105.90
# 314         0.2163  ...         8.952          22.44            56.65
# 318         0.2330  ...        10.060          23.40            68.62
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 211       546.3           0.12800            0.18800          0.14710
# 407       645.8           0.09402            0.19360          0.18380
# 22        980.9           0.13900            0.59540          0.63050
# 336       576.0           0.11420            0.19750          0.14500
# 229       706.0           0.17770            0.53430          0.62820
# 350       542.5           0.09958            0.06476          0.03046
# 450       507.2           0.09457            0.33990          0.32180
# 447       829.5           0.12260            0.18810          0.20600
# 314       240.1           0.13470            0.07767          0.00000
# 318       297.1           0.12210            0.37480          0.46090
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 211               0.06913          0.2535                  0.07993
# 407               0.05601          0.2488                  0.08151
# 22                0.23930          0.4667                  0.09946
# 336               0.05850          0.2432                  0.10090
# 229               0.19770          0.3407                  0.12430
# 350               0.04262          0.2731                  0.06825
# 450               0.08750          0.2305                  0.09952
# 447               0.08308          0.3600                  0.07285
# 314               0.00000          0.3142                  0.08116
# 318               0.11450          0.3135                  0.10550
#
# [10 rows x 31 columns]

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
reg=GradientBoostingClassifier(n_estimators=5)
reg.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=5)

# %%
ans=reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
confusion_matrix(y_test,ans)
# Out:
# array([[40,  3],
#        [ 2, 69]])

# %%
print(classification_report(y_test,ans))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        43
#            1       0.96      0.97      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
accuracy_score(y_test,ans)
# Out:
# 0.956140350877193
