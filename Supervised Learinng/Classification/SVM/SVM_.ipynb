# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df=pd.read_csv('/content/breast-cancer.csv')
df=df.drop(['id','Unnamed: 32'],axis=1)
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1}).astype(int)
df.sample(10)
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 235          1        14.03         21.25           89.79      603.4
# 18           0        19.81         22.15          130.00     1260.0
# 452          1        12.00         28.23           76.77      442.5
# 328          0        16.27         20.71          106.90      813.7
# 47           0        13.17         18.66           85.98      534.6
# 425          1        10.03         21.28           63.19      307.3
# 36           0        14.25         21.72           93.63      633.0
# 148          1        14.44         15.18           93.97      640.1
# 172          0        15.46         11.89          102.50      736.9
# 471          1        12.04         28.14           76.85      449.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 235          0.09070           0.06945         0.01462             0.018960
# 18           0.09831           0.10270         0.14790             0.094980
# 452          0.08437           0.06450         0.04055             0.019450
# 328          0.11690           0.13190         0.14780             0.084880
# 47           0.11580           0.12310         0.12260             0.073400
# 425          0.08117           0.03912         0.00247             0.005159
# 36           0.09823           0.10980         0.13190             0.055980
# 148          0.09970           0.10210         0.08487             0.055320
# 172          0.12570           0.15550         0.20320             0.109700
# 471          0.08752           0.06000         0.02367             0.023770
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 235         0.1517  ...         15.33          30.28            98.27
# 18          0.1582  ...         27.32          30.88           186.80
# 452         0.1615  ...         13.09          37.88            85.07
# 328         0.1948  ...         19.28          30.38           129.80
# 47          0.2128  ...         15.67          27.95           102.80
# 425         0.1630  ...         11.11          28.94            69.92
# 36          0.1885  ...         15.89          30.36           116.20
# 148         0.1724  ...         15.85          19.85           108.60
# 172         0.1966  ...         18.79          17.04           125.00
# 471         0.1854  ...         13.60          33.33            87.24
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 235       715.5            0.1287            0.15130          0.06231
# 18       2398.0            0.1512            0.31500          0.53720
# 452       523.7            0.1208            0.18560          0.18110
# 328      1121.0            0.1590            0.29470          0.35970
# 47        759.4            0.1786            0.41660          0.50060
# 425       376.3            0.1126            0.07094          0.01235
# 36        799.6            0.1446            0.42380          0.51860
# 148       766.9            0.1316            0.27350          0.31030
# 172      1102.0            0.1531            0.35830          0.58300
# 471       567.6            0.1041            0.09726          0.05524
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 235               0.07963          0.2226                  0.07617
# 18                0.23880          0.2768                  0.07615
# 452               0.07116          0.2447                  0.08194
# 328               0.15830          0.3103                  0.08200
# 47                0.20880          0.3900                  0.11790
# 425               0.02579          0.2349                  0.08061
# 36                0.14470          0.3591                  0.10140
# 148               0.15990          0.2691                  0.07683
# 172               0.18270          0.3216                  0.10100
# 471               0.05547          0.2404                  0.06639
#
# [10 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
reg=SVC(kernel='rbf')
reg.fit(x_train,y_train)
# Out:
# SVC()

# %%
ans=reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
confusion_matrix(y_test,ans)
# Out:
# array([[37,  6],
#        [ 0, 71]])

# %%
print(classification_report(y_test,ans))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93        43
#            1       0.92      1.00      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.96      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
accuracy_score(y_test,ans)
# Out:
# 0.9473684210526315
