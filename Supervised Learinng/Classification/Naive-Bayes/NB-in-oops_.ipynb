# %%
import sys
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
class NB:
  def __init__(self,d):
    try:
      df=pd.read_csv(d)
      df=df.drop(['Id'],axis=1)
      df['Species']=df['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2}).astype(int)
      x=df.iloc[:,:-1]
      y=df.iloc[:,-1]
      self.x_train,self.x_test,self.y_train,self.y_test=train_test_split(x,y,test_size=0.2,random_state=42)
    except Exception as e:
      ms,ty,lin=sys.exc_info()
      print(f'{ms} {ty} {lin.tb_lineno}')
  def train(self):
    try:
      reg=GaussianNB()
      reg.fit(self.x_train,self.y_train)
      print(confusion_matrix(self.y_train,reg.predict(self.x_train)))
      print(classification_report(self.y_train,reg.predict(self.x_train)))
      print(accuracy_score(self.y_train,reg.predict(self.x_train)))
    except Exception as e:
      ms,ty,lin=sys.exc_info()
      print(f'{ms} {ty} {lin.tb_lineno}')
  def test(self):
    try:
      reg=GaussianNB()
      reg.fit(self.x_train,self.y_train)
      print(confusion_matrix(self.y_test,reg.predict(self.x_test)))
      print(classification_report(self.y_test,reg.predict(self.x_test)))
      print(accuracy_score(self.y_test,reg.predict(self.x_test)))
    except Exception as e:
      ms,ty,lin=sys.exc_info()
      print(f'{ms} {ty} {lin.tb_lineno}')
  def check(self):
    try:
      reg=GaussianNB()
      reg.fit(self.x_train,self.y_train)
      sl = 1.4
      sw = 1.8
      pl = 0.04
      pw = 0.08

      if reg.predict([[sl,sw,pl,pw]])[0]==0:
        print('setosa')
      elif reg.predict([[sl,sw,pl,pw]])[0]==1:
        print(f'Versicolor')
      else:
        print(f'Verginica')
    except Exception as e:
      ms,ty,lin=sys.exc_info()
      print(f'{ms} {ty} {lin.tb_lineno}')

if __name__=="__main__":
  obj=NB('/content/Iris.csv')
  obj.train()
  obj.test()
  obj.check()
# Out:
# [[40  0  0]
#  [ 0 38  3]
#  [ 0  3 36]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       0.93      0.93      0.93        41
#            2       0.92      0.92      0.92        39
#
#     accuracy                           0.95       120
#    macro avg       0.95      0.95      0.95       120
# weighted avg       0.95      0.95      0.95       120
#
# 0.95
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# 1.0
# setosa
